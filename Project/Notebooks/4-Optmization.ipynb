# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import cvxpy as cp
import numpy as np
import pandas as pd

df = pd.read_csv("../Data/Predicted_Resource_utilization.csv")

resources = ["small", "medium", "large"]
R = len(resources)

y_pred = df["workload"].values[:50]
cpu = df["cpu_utilization"].values[:50]
memory = df["memory_usage"].values[:50]
storage = df["storage_usage"].values[:50]
T = len(y_pred)

x = cp.Variable((T, R), integer=True)

alloc = cp.sum(x, axis=1)

capacity_limit = (
      0.3 * cpu + 0.46 * memory + 0.3 * storage
)


objective = cp.Maximize(cp.sum(alloc))

constraints = [
    alloc <= y_pred,         
    alloc <= capacity_limit,  
    x >= 0                    
]

# Solve
prob = cp.Problem(objective, constraints)
prob.solve(solver=cp.SCIP, verbose=True)

# Results
if x.value is not None:
    x_opt = np.rint(x.value).astype(int)
    alloc_df = pd.DataFrame(x_opt, columns=resources)
    alloc_df["total_allocation"] = alloc_df[resources].sum(axis=1)
    alloc_df["predicted_demand"] = y_pred
    alloc_df["served_demand"] = np.minimum(alloc_df["total_allocation"], y_pred)
    print(alloc_df.head())
    print("Total Served Demand:", alloc_df["served_demand"].sum())
else:
    print("Solver failed:", prob.status)
# Out:
# (CVXPY) Sep 06 11:05:28 PM: Your problem has 150 variables, 250 constraints, and 0 parameters.
# (CVXPY) Sep 06 11:05:28 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 06 11:05:28 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 06 11:05:28 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 06 11:05:28 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Sep 06 11:05:28 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Sep 06 11:05:28 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Sep 06 11:05:28 PM: Applying reduction FlipObjective
# (CVXPY) Sep 06 11:05:28 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 06 11:05:28 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 06 11:05:28 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 06 11:05:28 PM: Applying reduction SCIP
# (CVXPY) Sep 06 11:05:28 PM: Finished problem compilation (took 1.262e-02 seconds).
# (CVXPY) Sep 06 11:05:28 PM: Invoking solver SCIP  to obtain a solution.
# (CVXPY) Sep 06 11:05:28 PM: Problem status: optimal
# (CVXPY) Sep 06 11:05:28 PM: Optimal value: 3.366e+03
# (CVXPY) Sep 06 11:05:28 PM: Compilation took 1.262e-02 seconds
# (CVXPY) Sep 06 11:05:28 PM: Solver (including time spent in interface) took 1.288e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.7.2
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 0.000000e+00
# presolving:
# (round 1, fast)       0 del vars, 150 del conss, 0 add conss, 150 chg bounds, 83 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, fast)       0 del vars, 150 del conss, 0 add conss, 420 chg bounds, 103 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 3, exhaustive) 0 del vars, 200 del conss, 0 add conss, 420 chg bounds, 103 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 4, exhaustive) 100 del vars, 200 del conss, 0 add conss, 420 chg bounds, 103 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
#    (0.0s) symmetry computation started: requiring (bin +, int +, cont +), (fixed: bin -, int -, cont -)
#    (0.0s) no symmetry present (symcode time: 0.00)
# presolving (5 rounds: 5 fast, 3 medium, 3 exhaustive):
#  100 deleted vars, 250 deleted constraints, 0 added constraints, 420 tightened bounds, 0 added holes, 103 changed sides, 0 changed coefficients
#  0 implications, 0 cliques
# presolved problem has 50 variables (0 bin, 50 int, 0 impl, 0 cont) and 0 constraints
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.00
# transformed 1/1 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# t 0.0s|     1 |     0 |     0 |     - | trivial|   0 |  50 |   0 |   0 |   0 |  0 |   0 |   0 |-3.366000e+03 |-3.366000e+03 |   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 1
# Primal Bound       : -3.36600000000000e+03 (2 solutions)
# Dual Bound         : -3.36600000000000e+03
# Gap                : 0.00 %
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
#    small  medium  large  total_allocation  predicted_demand  served_demand
# 0     72       0      0                72         72.320110           72.0
# 1     71       0      0                71         97.880552           71.0
# 2     73       0      0                73        100.000000           73.0
# 3     70       0      0                70        100.000000           70.0
# 4     77       0      0                77        100.000000           77.0
# Total Served Demand: 3366.0

# %%
import matplotlib.pyplot as plt

alloc_df["historical_allocation"] = df["Resource Allocation"].values[:T]

# Plot comparison
plt.figure(figsize=(20,10))
plt.plot(alloc_df.index, alloc_df["predicted_demand"], label="Workload (Demand)", lw=2, color="black")
plt.plot(alloc_df.index, alloc_df["historical_allocation"], label="Historical Allocation", lw=2, color="red")
plt.plot(alloc_df.index, alloc_df["served_demand"], label="Optimized Allocation (Served Demand)", lw=2, linestyle="--", color="blue")

plt.xlabel("Time Step")
plt.ylabel("Resource Units")
plt.title("Comparison: Workload vs Historical vs Optimized Allocation")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
import cvxpy as cp
import numpy as np
import pandas as pd

df = pd.read_csv("../Data/Predicted_Resource_utilization.csv")

resources = ["small", "medium", "large"]
R = len(resources)

y_pred = df["predicted_workload"].values[:50]
cpu = df["cpu_utilization"].values[:50]
memory = df["memory_usage"].values[:50]
storage = df["storage_usage"].values[:50]
T = len(y_pred)

x = cp.Variable((T, R), integer=True)

alloc = cp.sum(x, axis=1)

capacity_limit = (
      0.7 * cpu + 0.1 * memory + 0.7* storage
)


objective = cp.Maximize(cp.sum(alloc))

constraints = [
    alloc <= y_pred,         
    alloc <= capacity_limit,  
    x >= 0                    
]

# Solve
prob = cp.Problem(objective, constraints)
prob.solve(solver=cp.SCIP, verbose=True)

# Results
if x.value is not None:
    x_opt = np.rint(x.value).astype(int)
    alloc_df = pd.DataFrame(x_opt, columns=resources)
    alloc_df["total_allocation"] = alloc_df[resources].sum(axis=1)
    alloc_df["predicted_demand"] = y_pred
    alloc_df["served_demand"] = np.minimum(alloc_df["total_allocation"], y_pred)
    print(alloc_df.head())
    print("Total Served Demand:", alloc_df["served_demand"].sum())
else:
    print("Solver failed:", prob.status)
# Out:
# (CVXPY) Sep 06 11:05:29 PM: Your problem has 150 variables, 250 constraints, and 0 parameters.
# (CVXPY) Sep 06 11:05:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 06 11:05:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 06 11:05:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 06 11:05:29 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Sep 06 11:05:29 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Sep 06 11:05:29 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction FlipObjective
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction SCIP
# (CVXPY) Sep 06 11:05:29 PM: Finished problem compilation (took 8.697e-03 seconds).
# (CVXPY) Sep 06 11:05:29 PM: Invoking solver SCIP  to obtain a solution.
# (CVXPY) Sep 06 11:05:29 PM: Problem status: optimal
# (CVXPY) Sep 06 11:05:29 PM: Optimal value: 4.243e+03
# (CVXPY) Sep 06 11:05:29 PM: Compilation took 8.697e-03 seconds
# (CVXPY) Sep 06 11:05:29 PM: Solver (including time spent in interface) took 1.024e-02 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.7.2
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 0.000000e+00
# presolving:
# (round 1, fast)       0 del vars, 150 del conss, 0 add conss, 150 chg bounds, 100 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, fast)       0 del vars, 150 del conss, 0 add conss, 360 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 3, exhaustive) 0 del vars, 200 del conss, 0 add conss, 360 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 4, exhaustive) 100 del vars, 200 del conss, 0 add conss, 360 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 5, fast)       100 del vars, 250 del conss, 0 add conss, 362 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# presolving (6 rounds: 6 fast, 3 medium, 3 exhaustive):
#  150 deleted vars, 250 deleted constraints, 0 added constraints, 362 tightened bounds, 0 added holes, 120 changed sides, 0 changed coefficients
#  0 implications, 0 cliques
# transformed 1/2 original solutions to the transformed problem space
# Presolving Time: 0.00
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 0
# Primal Bound       : -4.24300000000000e+03 (2 solutions)
# Dual Bound         : -4.24300000000000e+03
# Gap                : 0.00 %
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
#    small  medium  large  total_allocation  predicted_demand  served_demand
# 0     99       0      0                99         99.994080           99.0
# 1     98       0      0                98         98.078700           98.0
# 2     89       0      0                89         89.513980           89.0
# 3     99       0      0                99         99.881560           99.0
# 4     99       0      0                99         99.503975           99.0
# Total Served Demand: 4243.0

# %%
import matplotlib.pyplot as plt

alloc_df["historical_allocation"] = df["Resource Allocation"].values[:T]

# Plot comparison
plt.figure(figsize=(20,10))
plt.plot(alloc_df.index, alloc_df["predicted_demand"], label="Workload (Demand)", lw=2, color="black")
plt.plot(alloc_df.index, alloc_df["served_demand"], label="Optimized Allocation (Served Demand)", lw=2, linestyle="--", color="blue")

plt.xlabel("Time Step")
plt.ylabel("Resource Units")
plt.title("Comparison: Workload vs Historical vs Optimized Allocation")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
import cvxpy as cp
import numpy as np
import pandas as pd

df = pd.read_csv("../Data/Predicted_Resource_utilization.csv")

resources = ["small", "medium", "large"]
R = len(resources)

y_pred = df["predicted_workload"].values[:50]
cpu = df["cpu_utilization"].values[:50]
memory = df["memory_usage"].values[:50]
storage = df["storage_usage"].values[:50]
T = len(y_pred)

x = cp.Variable((T, R), integer=True)

alloc = cp.sum(x, axis=1)

capacity_limit = (
      0.5 * cpu + 0.7 * memory + 0.1 * storage
)


objective = cp.Maximize(cp.sum(alloc))

constraints = [
    alloc <= y_pred,         
    alloc <= capacity_limit,  
    x >= 0                    
]

# Solve
prob = cp.Problem(objective, constraints)
prob.solve(solver=cp.SCIP, verbose=True)

# Results
if x.value is not None:
    x_opt = np.rint(x.value).astype(int)
    alloc_df = pd.DataFrame(x_opt, columns=resources)
    alloc_df["total_allocation"] = alloc_df[resources].sum(axis=1)
    alloc_df["predicted_demand"] = y_pred
    alloc_df["served_demand"] = np.minimum(alloc_df["total_allocation"], y_pred)
    print(alloc_df.head())
    print("Total Served Demand:", alloc_df["served_demand"].sum())
else:
    print("Solver failed:", prob.status)
# Out:
# (CVXPY) Sep 06 11:05:29 PM: Your problem has 150 variables, 250 constraints, and 0 parameters.
# (CVXPY) Sep 06 11:05:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 06 11:05:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Sep 06 11:05:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Sep 06 11:05:29 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Sep 06 11:05:29 PM: Compiling problem (target solver=SCIP).
# (CVXPY) Sep 06 11:05:29 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction FlipObjective
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 06 11:05:29 PM: Applying reduction SCIP
# (CVXPY) Sep 06 11:05:29 PM: Finished problem compilation (took 8.740e-03 seconds).
# (CVXPY) Sep 06 11:05:29 PM: Invoking solver SCIP  to obtain a solution.
# (CVXPY) Sep 06 11:05:29 PM: Problem status: optimal
# (CVXPY) Sep 06 11:05:29 PM: Optimal value: 3.655e+03
# (CVXPY) Sep 06 11:05:29 PM: Compilation took 8.740e-03 seconds
# (CVXPY) Sep 06 11:05:29 PM: Solver (including time spent in interface) took 9.626e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.7.2
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 0.000000e+00
# presolving:
# (round 1, fast)       0 del vars, 150 del conss, 0 add conss, 150 chg bounds, 100 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, fast)       0 del vars, 150 del conss, 0 add conss, 402 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 3, exhaustive) 0 del vars, 200 del conss, 0 add conss, 402 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 4, exhaustive) 100 del vars, 200 del conss, 0 add conss, 402 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 5, fast)       100 del vars, 250 del conss, 0 add conss, 403 chg bounds, 120 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# presolving (6 rounds: 6 fast, 3 medium, 3 exhaustive):
#  150 deleted vars, 250 deleted constraints, 0 added constraints, 403 tightened bounds, 0 added holes, 120 changed sides, 0 changed coefficients
#  0 implications, 0 cliques
# transformed 1/2 original solutions to the transformed problem space
# Presolving Time: 0.00
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 0
# Primal Bound       : -3.65500000000000e+03 (2 solutions)
# Dual Bound         : -3.65500000000000e+03
# Gap                : 0.00 %
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
#    small  medium  large  total_allocation  predicted_demand  served_demand
# 0     99       0      0                99         99.994080           99.0
# 1     83       0      0                83         98.078700           83.0
# 2     89       0      0                89         89.513980           89.0
# 3     77       0      0                77         99.881560           77.0
# 4     89       0      0                89         99.503975           89.0
# Total Served Demand: 3655.0

# %%
import matplotlib.pyplot as plt

alloc_df["historical_allocation"] = df["Resource Allocation"].values[:T]

# Plot comparison
plt.figure(figsize=(20,10))
plt.plot(alloc_df.index, alloc_df["predicted_demand"], label="Workload (Demand)", lw=2, color="black")
plt.plot(alloc_df.index, alloc_df["served_demand"], label="Optimized Allocation (Served Demand)", lw=2, linestyle="--", color="blue")

plt.xlabel("Time Step")
plt.ylabel("Resource Units")
plt.title("Comparison: Workload vs Historical vs Optimized Allocation")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
